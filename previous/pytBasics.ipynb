# %%
x = 3+5j
print('Complex number:',x)

my_dictionary_var = {'name': 'Alice', 'age': 25}
print('Dictionary:', my_dictionary_var)
print('The age is:', my_dictionary_var['age'])

my_set_var = {7, 5, 8} # Unordered collection of unique elements
print('Set:', my_set_var) # Set: {7, 5, 8}

my_tuple_var = (7, 5, 8) # An immutable ordered collection
print('Tuple:', my_tuple_var) # Tuple: (7, 5, 8)

my_list = [22, 'Hello world', 3.14, True]
print(my_list) # [22, 'Hello world', 3.14, True]
print('First element:', my_list[0])

my_range_var = range(5)
print(my_range_var) # range(0, 5)
# Out:
# Complex number: (3+5j)
# Dictionary: {'name': 'Alice', 'age': 25}
# The age is: 25
# Set: {8, 5, 7}
# Tuple: (7, 5, 8)
# range(0, 5)
# [22, 'Hello world', 3.14, True]
# First element: 22

# %%
my_integer_var = 10
print('Integer:', my_integer_var, '| Type:', type(my_integer_var))  # Integer: 10 | Type: <class 'int'>

my_float_var = 4.50
print('Float:', my_float_var, '| Type:', type(my_float_var))  # Float: 4.50 | Type: <class 'float'>

my_complex_var = 3 + 4j
print('Complex:', my_complex_var, '| Type:', type(my_complex_var))  # Complex: (3+4j) | Type: <class 'complex'>

my_string_var = 'hello'
print('String:', my_string_var, '| Type:', type(my_string_var))  # String: hello | Type: <class 'str'>

my_boolean_var = True
print('Boolean:', my_boolean_var, '| Type:', type(my_boolean_var))  # Boolean: True | Type: <class 'bool'>

my_set_var = {7, 5, 8}
print('Set:', my_set_var, '| Type:', type(my_set_var))  # Set: {7, 5, 8} | Type: <class 'set'>

my_dictionary_var = {'name': 'Alice', 'age': 25}
print('Dictionary:', my_dictionary_var, '| Type:', type(my_dictionary_var))  # Dictionary: {'name': 'Alice', 'age': 25} | Type: <class 'dict'>
print(' The name is',my_dictionary_var['name'])

my_tuple_var = (7, 5, 8)
print('Tuple:', my_tuple_var, '| Type:', type(my_tuple_var))  # Tuple: (7, 5, 8) | Type: <class 'tuple'>

my_range_var = range(5)
print('Range:', list(my_range_var), '| Type:', type(my_range_var))  # Range: [0, 1, 2, 3, 4] | Type: <class 'range'>

my_list = [22, 'Hello world', 3.14, True]
print('List:', list(my_list), '| Type:', type(my_list)) # List: [22, 'Hello world', 3.14, True] | Type: <class 'list'>
print(' First element:', my_list[0])

my_none_var = None
print('None:', my_none_var, '| Type:', type(my_none_var))  # None: None | Type: <class 'NoneType'>

isinstance('Hello world', str) # True
# Out:
# Integer: 10 | Type: <class 'int'>
# Float: 4.5 | Type: <class 'float'>
# Complex: (3+4j) | Type: <class 'complex'>
# String: hello | Type: <class 'str'>
# Boolean: True | Type: <class 'bool'>
# Set: {8, 5, 7} | Type: <class 'set'>
# Dictionary: {'name': 'Alice', 'age': 25} | Type: <class 'dict'>
#  The name is Alice
# Tuple: (7, 5, 8) | Type: <class 'tuple'>
# Range: [0, 1, 2, 3, 4] | Type: <class 'range'>
# List: [22, 'Hello world', 3.14, True] | Type: <class 'list'>
#  First element: 22
# None: None | Type: <class 'NoneType'>
# True

# %%
# Type hints:
def greet(name: str, age: int) -> str:
    return f'Hello, {name}, age {age}.'

user_name: str = 'John Doe'
user_age: int = 24

print(greet(user_name, user_age))
# Out:
# Hello, John Doe, age 24.

# %%
# Formatted strings
name = 'John Doe'
age = 26
name_and_age = f'My name is {name} and I am {age} years old'
print(name_and_age) # My name is John Doe and I am 26 years old

num1 = 5
num2 = 10
print(f'The sum of {num1} and {num2} is {num1 + num2}') # The sum of 5 and 10 is 15
# Out:
# My name is John Doe and I am 26 years old
# The sum of 5 and 10 is 15

# %%
my_str = 'Hello world'
print(my_str[0:11:2]) # Hlowrd
print(my_str[::-1]) # dlrow olleH
print('Hello' in my_str)  # True
print('hey' in my_str)    # False
# Out:
# Hlowrd
# dlrow olleH
# True
# False

# %%
x = 12
x /= 3 # Augumented assignment
print(x)
print(type(x))
# Out:
# 4.0
# <class 'float'>

# %%
name = input('Enter your name: ')
print(f'Hello, {name}!')
# Out:
# Hello, !

# %%
# LEGB rule (Local, Enclosing, Global, Built-in)
def my_func():
    print("Hello, World!")
    my_var = 10 # Locally scoped to my_func
    print(my_var)


my_func()
# print(my_var)  # This will raise a NameError because my_var is not defined outside the function
# Out:
# Hello, World!
# 10

# %%
def outer_func():
    msg = 'Hello there!'

    def inner_func():
        print(msg)

    inner_func()

outer_func() # Hello there!
# Out:
# Hello there!

# %%
def outer_func():
    msg = 'Hello there!'
    res = ""  # Declare res in the enclosing scope

    def inner_func():
        nonlocal res  # Allow modification of an enclosing variable
        res = 'How are you?'
        print(msg)  # Accessing msg from outer_func()

    inner_func()
    print(res)  # Now res is accessible and modified

outer_func()

# Output:
# Hello there!
# How are you?
# Out:
# Hello there!
# How are you?

# %%
my_var_1 = 7

def show_vars():
    global my_var_2
    my_var_2 = 10
    print(my_var_1)
    print(my_var_2)

show_vars() # 7 10

# my_var_2 is now a global variable and can be accessed anywhere in the program
print(my_var_2) # 10
# Out:
# 7
# 10
# 10

# %%
my_var = 10  # A global variable

def change_var():
    global my_var  # Allows modification of a global variable
    my_var = 20

change_var()

print(my_var)  # my_var is now modified globally to 20
# Out:
# 20

# %%
is_citizen = True
age = 25

print(is_citizen and age) # 25
# Out:
# 25
